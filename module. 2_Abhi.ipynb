# %%
# (1) write a python program to check if number is positive, negative or zero .
number_input = int(input())
if number_input >= 1 :
    print('positive_number')
elif number_input == 0 :
    print('zero_number')
else :
    print('negative_number')

# %%
# (2) write a python program to get the factorial  number of given number.
number_input = int(input())
factorial_val = 1
for number_val in range(1,number_input + 1):
    factorial_val *= (number_val)
print(factorial_val)

# %%
# (3) write a python program to get the fibonacci series of given range.
number_input = int(input())
number_1 = 0
number_2 = 1
number_3 = 0
for fibonacci_number in range(number_input) :
    print(number_3,end=' ')
    number_1 = number_2
    number_2 = number_3
    number_3 = number_1 + number_2

# %%
# (4) how memory is managed in python?
#ans:-
    # Memory management in Python involves a private heap containing all Python objects and data structures.
    # The management of this private heap is ensured internally by the Python memory manager.

# %%
# (5) what is the purpose continue statement in python ? 
# ans :-
    # The continue statement in Python returns the control to the beginning of the while loop.
    # The continue statement rejects all the remaining statements in the current iteration of the loop
    # and moves the control back to the top of the loop.
    # The continue statement can be used in both while and for loops.

# %%
# (6) write a python program that swap two number with temp variable and without temp variable.
number_input_one = int(input())
number_input_two = int(input())

temp_variable = number_input_one
number_input_one = number_input_two
number_input_two = temp_variable

print(number_input_one)
print(number_input_two)

# %%
# (7) write a python program to find whether a given number is even or odd,print out an appropriate message to the user.

number_input = int(input())
if number_input % 2 == 0 :
    print('This number is even')
else:
    print('This number is odd')

# %%
# (8) write a python program to test whether a passed letter is a vowel or not.

letter_input = input()
vowel_letter = ['a', 'e', 'i', 'o', 'u']
vowel_letter_cap = ['A', 'E', 'I', 'O', 'U']
if letter_input in vowel_letter or letter_input in vowel_letter_cap :
    print(letter_input ,'is vowel')
else :
    print(letter_input ,'is not vowel')

# %%
# (9) write a python program to sum of three given integers. however , if two values are equal sum will be zero.

number_1 = int(input())
number_2 = int(input())
number_3 = int(input())

if number_1 == number_2 or number_1 == number_3 or number_2 == number_3:
    sum_val = number_1 + number_2 + number_3
    print(sum_val - sum_val)
else :
    print(number_1 + number_2 + number_3)

# %%
# (10) write a python program that will return true if the two given integervalues are equal or thir sum or difference is 5. 

number_1 = int(input())
number_2 = int(input())

if number_1 == number_2 :
    print('true')
elif (number_1 + number_2) == 5 :
    print('true')
elif (number_1 - number_2) == 5 :
        print('true')

# %%
# (11) write a python program to sum of the first n positive integers.

n_number= int(input())
sun_of_n_number = 0
for positive_val in range(1,n_number + 1 , 2) :
    sun_of_n_number += positive_val
print(sun_of_n_number)

# %%
# (12)  write a python program to calculate the length of a string.

string_input = input()
count_of_string = len(string_input)
print(count_of_string)

# %%
# (13) write a python program to count the number of character (character frequency) in a string .

string_input = input()
spli_string = string_input.split()
countz_word = ''
for word in spli_string :
    count_word = spli_string.count(word)
    print(word,'-',count_word)


# total_character = string_input.count(character_input)
# print(total_character)
# Out:
# this is a lenth of the sub lenth is .
# this - 1
# is - 2
# a - 1
# lenth - 2
# of - 1
# the - 1
# sub - 1
# lenth - 2
# is - 2
# . - 1

# %%
# (14) what a negative index and why are they use ?
# ans :- 
    # Python supports “indexing from the end”, that is, negative indexing. 
    # This means the last value of a sequence has an index of -1, the second last -2, and so on.
    # Thay use when we want to pick values from the end (right side) of an iterable.

# %%
# (15) write a python program to count occurrence of a substring in a string.

string_input = input()
string_input1 = input()

if string_input1 in string_input :
    single_string = string_input.count(string_input1)
    print(single_string)

# %%
# (16) write a python program to count occurrence of each word in a given sentence.

string_input = input()
split_string = string_input.split(' ')
string_lenth = len(split_string)
print(string_lenth)

# %%
# (17) Write a Python program to get a single string from two given strings,
# separated by a space and swap the first two characters of each string.

string_input = input()
string_input1 = input()

joint_string = ' '.join([string_input,string_input1])
joint_string1 = string_input[::] + string_input1[::]
print(joint_string)
print(joint_string1)

# %%
# (18) Write a Python program to add 'ing' at the end of a given string (length should be at least 3).
# If the given string already ends with 'ing' then add 'ly' instead If the string length of the given
# string is less than 3, leave it unchanged rite a Python program to add 'ing' at the end of a given string 
# (length should be at least 3).

string_input = input()
string_lenth = len(string_input)
string_add = 'ing'
if len(string_input) > 3 :
    if string_input.endswith('ing'):
        new_string0 = string_input.replace('ing','iy')
        print(new_string0)
    else:
        new_string = string_input[::] + 'ing'
        print(new_string)

# %%
# (19) write a python program to find the first appearance of the substring 'not' and 'poor' from a given string,
# if'not' follows the 'poor', replace the whole 'not'...'poor' substring with 'good'. return the resulting string.

string_input = input()
not_word = string_input.find('not')
poor_word = string_input.find('poor')
if not_word <poor_word :
    new_string = string_input.replace(string_input[not_word:(poor_word+4)],'good')
    print(new_string)

# %%
# (20) write a python function that takes a list of words and returns the lenth of the longest one.

string_input = input()
new_string = string_input.split(' ')
lent_word = 0
for string in new_string :
    if len(string) > lent_word :
        lent_word = len(string)
        long_word = string
print(long_word , len(long_word))

# %%
# (21) write a python function to reverses a string if its length is a multiple of 4.

string_input = input()
if (len(string_input) % 4 == 0) :
    for i in string_input[::-1] :
        new_string = i
        print(new_string,end='')

# %%
# (22) Write a Python program to get a string made of the first 2 and the last 2
# chars from a given a string. Ifthe string length islessthan 2,return instead
# of the empty string.
#  Sample String:w3resource'
#  Expected Result: 'w3ce'
#  Sample String: 'w3'
#  Expected Result: 'w3w3'
#  Sample String: ' w'
#  Expected Result: Empty String

string_input = input()
if len(string_input) > 4 :
    expected_string = string_input[0:2] + string_input[-2:]
    print(expected_string)
elif len(string_input) == 2 :
    print(string_input + string_input)
elif len(string_input) == 1 :
    print("empty string")

# %%
# (23) Write a Python function to insert a string in the middle of a string. 

string_input = input()
when_wants_add = input()
add_string = input()
index_of_string = string_input.find(when_wants_add)
new_string = string_input[:index_of_string] + add_string  + string_input[index_of_string:]
print(new_string)

# %%
# module 2 over

# %%
# (1) write a python program to check if number is positive, negative or zero .
number_input = int(input())
if number_input >= 1 :
    print('positive_number')
elif number_input == 0 :
    print('zero_number')
else :
    print('negative_number')

# (2) write a python program to get the factorial  number of given number.
number_input = int(input())
factorial_val = 1
for number_val in range(1,number_input + 1):
    factorial_val *= (number_val)
print(factorial_val)   

# (3) write a python program to get the fibonacci series of given range.
number_input = int(input())
number_1 = 0
number_2 = 1
number_3 = 0
for fibonacci_number in range(number_input) :
    print(number_3,end=' ')
    number_1 = number_2
    number_2 = number_3
    number_3 = number_1 + number_2

# (4) how memory is managed in python?
#ans:-
    # Memory management in Python involves a private heap containing all Python objects and data structures.
    # The management of this private heap is ensured internally by the Python memory manager. 

# (5) what is the purpose continue statement in python ? 
# ans :-
    # The continue statement in Python returns the control to the beginning of the while loop.
    # The continue statement rejects all the remaining statements in the current iteration of the loop
    # and moves the control back to the top of the loop.
    # The continue statement can be used in both while and for loops.

# (6) write a python program that swap two number with temp variable and without temp variable.
number_input_one = int(input())
number_input_two = int(input())

temp_variable = number_input_one
number_input_one = number_input_two
number_input_two = temp_variable

print(number_input_one)
print(number_input_two)


# (7) write a python program to find whether a given number is even or odd,print out an appropriate message to the user.

number_input = int(input())
if number_input % 2 == 0 :
    print('This number is even')
else:
    print('This number is odd')

# (8) write a python program to test whether a passed letter is a vowel or not.

letter_input = input()
vowel_letter = ['a', 'e', 'i', 'o', 'u']
vowel_letter_cap = ['A', 'E', 'I', 'O', 'U']
if letter_input in vowel_letter or letter_input in vowel_letter_cap :
    print(letter_input ,'is vowel')
else :
    print(letter_input ,'is not vowel')

# (9) write a python program to sum of three given integers. however , if two values are equal sum will be zero.

number_1 = int(input())
number_2 = int(input())
number_3 = int(input())

if number_1 == number_2 or number_1 == number_3 or number_2 == number_3:
    sum_val = number_1 + number_2 + number_3
    print(sum_val - sum_val)
else :
    print(number_1 + number_2 + number_3)

# (10) write a python program that will return true if the two given integervalues are equal or thir sum or difference is 5. 

number_1 = int(input())
number_2 = int(input())

if number_1 == number_2 :
    print('true')
elif (number_1 + number_2) == 5 :
    print('true')
elif (number_1 - number_2) == 5 :
        print('true')

# (11) write a python program to sum of the first n positive integers.

n_number= int(input())
sun_of_n_number = 0
for positive_val in range(1,n_number + 1 , 2) :
    sun_of_n_number += positive_val
print(sun_of_n_number)
    
    

# (12)  write a python program to calculate the length of a string.

string_input = input()
count_of_string = len(string_input)
print(count_of_string)

# (13) write a python program to count the number of character (character frequency) in a string .

string_input = input()
spli_string = string_input.split()
countz_word = ''
for word in spli_string :
    count_word = spli_string.count(word)
    print(word,'-',count_word)


# total_character = string_input.count(character_input)
# print(total_character)

# (14) what a negative index and why are they use ?
# ans :- 
    # Python supports “indexing from the end”, that is, negative indexing. 
    # This means the last value of a sequence has an index of -1, the second last -2, and so on.
    # Thay use when we want to pick values from the end (right side) of an iterable.
    

# (15) write a python program to count occurrence of a substring in a string.

string_input = input()
string_input1 = input()

if string_input1 in string_input :
    single_string = string_input.count(string_input1)
    print(single_string)

# (16) write a python program to count occurrence of each word in a given sentence.

string_input = input()
split_string = string_input.split(' ')
string_lenth = len(split_string)
print(string_lenth)

# (17) Write a Python program to get a single string from two given strings,
# separated by a space and swap the first two characters of each string.

string_input = input()
string_input1 = input()

joint_string = ' '.join([string_input,string_input1])
joint_string1 = string_input[::] + string_input1[::]
print(joint_string)
print(joint_string1)

# (18) Write a Python program to add 'ing' at the end of a given string (length should be at least 3).
# If the given string already ends with 'ing' then add 'ly' instead If the string length of the given
# string is less than 3, leave it unchanged rite a Python program to add 'ing' at the end of a given string 
# (length should be at least 3).

string_input = input()
string_lenth = len(string_input)
string_add = 'ing'
if len(string_input) > 3 :
    if string_input.endswith('ing'):
        new_string0 = string_input.replace('ing','iy')
        print(new_string0)
    else:
        new_string = string_input[::] + 'ing'
        print(new_string)    

# (19) write a python program to find the first appearance of the substring 'not' and 'poor' from a given string,
# if'not' follows the 'poor', replace the whole 'not'...'poor' substring with 'good'. return the resulting string.

string_input = input()
not_word = string_input.find('not')
poor_word = string_input.find('poor')
if not_word <poor_word :
    new_string = string_input.replace(string_input[not_word:(poor_word+4)],'good')
    print(new_string)

# (20) write a python function that takes a list of words and returns the lenth of the longest one.

string_input = input()
new_string = string_input.split(' ')
lent_word = 0
for string in new_string :
    if len(string) > lent_word :
        lent_word = len(string)
        long_word = string
print(long_word , len(long_word))

# (21) write a python function to reverses a string if its length is a multiple of 4.

string_input = input()
if (len(string_input) % 4 == 0) :
    for i in string_input[::-1] :
        new_string = i
        print(new_string,end='')
    



# (22) Write a Python program to get a string made of the first 2 and the last 2
# chars from a given a string. Ifthe string length islessthan 2,return instead
# of the empty string.
#  Sample String:w3resource'
#  Expected Result: 'w3ce'
#  Sample String: 'w3'
#  Expected Result: 'w3w3'
#  Sample String: ' w'
#  Expected Result: Empty String

string_input = input()
if len(string_input) > 4 :
    expected_string = string_input[0:2] + string_input[-2:]
    print(expected_string)
elif len(string_input) == 2 :
    print(string_input + string_input)
elif len(string_input) == 1 :
    print("empty string")

# (23) Write a Python function to insert a string in the middle of a string. 

string_input = input()
when_wants_add = input()
add_string = input()
index_of_string = string_input.find(when_wants_add)
new_string = string_input[:index_of_string] + add_string  + string_input[index_of_string:]
print(new_string)

# module 2 over
